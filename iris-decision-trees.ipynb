# %% [markdown]
# # Decision Trees

# %% [markdown]
# ## Notebook setup

# %%
import pandas as pd
from matplotlib import pyplot as plt
import pydotplus

from sklearn import datasets
from sklearn.tree import DecisionTreeClassifier 
from sklearn import tree
from sklearn.tree import DecisionTreeClassifier

# %% [markdown]
# ## Load and prepare data

# %%
iris_data = pd.read_csv('iris.csv')
X = iris_data[['SepalWidth','SepalLength','PetalLength','PetalWidth']]
y = iris_data[['Name']]

iris_data.head()
# Out:
#    SepalLength  SepalWidth  PetalLength  PetalWidth         Name
# 0          5.1         3.5          1.4         0.2  Iris-setosa
# 1          4.9         3.0          1.4         0.2  Iris-setosa
# 2          4.7         3.2          1.3         0.2  Iris-setosa
# 3          4.6         3.1          1.5         0.2  Iris-setosa
# 4          5.0         3.6          1.4         0.2  Iris-setosa

# %% [markdown]
# **Question 4:** Let's create a new Decision Tree classifier.
# Fit the X and y variables.

# %% [markdown]
# ## Create model

# %%
clf = DecisionTreeClassifier()
model = clf.fit(X,y)

# %%
# Test predictions
model.predict([[4.6,3.1,1.5,0.2]])
# Out:
# /Users/jackwalker/anaconda3/envs/log-reg/lib/python3.12/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
# array(['Iris-setosa'], dtype=object)

# %% [markdown]
# ## Visualise decision tree

# %%
text_representation = tree.export_text(clf)
print(text_representation)
# Out:
# |--- feature_3 <= 0.80
# |   |--- class: Iris-setosa
# |--- feature_3 >  0.80
# |   |--- feature_3 <= 1.75
# |   |   |--- feature_2 <= 4.95
# |   |   |   |--- feature_3 <= 1.65
# |   |   |   |   |--- class: Iris-versicolor
# |   |   |   |--- feature_3 >  1.65
# |   |   |   |   |--- class: Iris-virginica
# |   |   |--- feature_2 >  4.95
# |   |   |   |--- feature_3 <= 1.55
# |   |   |   |   |--- class: Iris-virginica
# |   |   |   |--- feature_3 >  1.55
# |   |   |   |   |--- feature_2 <= 5.45
# |   |   |   |   |   |--- class: Iris-versicolor
# |   |   |   |   |--- feature_2 >  5.45
# |   |   |   |   |   |--- class: Iris-virginica
# |   |--- feature_3 >  1.75
# |   |   |--- feature_2 <= 4.85
# |   |   |   |--- feature_1 <= 5.95
# |   |   |   |   |--- class: Iris-versicolor
# |   |   |   |--- feature_1 >  5.95
# |   |   |   |   |--- class: Iris-virginica
# |   |   |--- feature_2 >  4.85
# |   |   |   |--- class: Iris-virginica

# %%
iris = datasets.load_iris()
X = iris.data
y = iris.target

fig = plt.figure(figsize=(25,20))
_ = tree.plot_tree(clf, 
                   feature_names=iris.feature_names,  
                   class_names=iris.target_names,
                   filled=True)
